# %%
import pandas as pd

df = pd.read_csv('data_110k_lignes.csv')

# %%
df['popularity'].describe()
# Out:
# count    110158.00000
# mean         30.64068
# std          18.44315
# min           0.00000
# 25%          16.00000
# 50%          31.00000
# 75%          44.00000
# max          92.00000
# Name: popularity, dtype: float64
